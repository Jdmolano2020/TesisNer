# %% [markdown]
# <a href="https://colab.research.google.com/github/Jdmolano2020/TesisNer/blob/main/SroieTextAugmentation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Mount Google drive to colab
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import locale
def getpreferredencoding(do_setlocale = True):
    return "UTF-8"
locale.getpreferredencoding = getpreferredencoding

# %% [markdown]
# ##Cargar Archivos Sroie

# %%
# limpiamos rastros del dataset y descomprimimos
# !rm -rf /tmp/SROIE2019v02
# !unzip /content/drive/MyDrive/archive_SROIEv2.zip -d /tmp/SROIE2019v02/
# Out:
# Archive:  /content/drive/MyDrive/archive_SROIEv2.zip
#    creating: /tmp/SROIE2019v02/SROIE2019/layoutlm-base-uncased/
#   inflating: /tmp/SROIE2019v02/SROIE2019/layoutlm-base-uncased/config.json
#   inflating: /tmp/SROIE2019v02/SROIE2019/layoutlm-base-uncased/pytorch_model.bin
#   inflating: /tmp/SROIE2019v02/SROIE2019/layoutlm-base-uncased/special_tokens_map.json
#   inflating: /tmp/SROIE2019v02/SROIE2019/layoutlm-base-uncased/tokenizer_config.json
#   inflating: /tmp/SROIE2019v02/SROIE2019/layoutlm-base-uncased/training_args.bin
#   inflating: /tmp/SROIE2019v02/SROIE2019/layoutlm-base-uncased/vocab.txt
#    creating: /tmp/SROIE2019v02/SROIE2019/test/
#    creating: /tmp/SROIE2019v02/SROIE2019/test/box/
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X00016469670.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X00016469671.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51005200931.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51005230605.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51005230616.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51005230621.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51005230648.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51005230657.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51005230659.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51005268275.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51005268408.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51005288570.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51005301666.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51005337867.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51005337877.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51005361906.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51005361908.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51005361912.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51005361923.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51005365187.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51005433518.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51005433543.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51005433548.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51005433556.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51005442322.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51005442334.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51005442343.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51005442366.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51005442375.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51005442382.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51005442388.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51005444040.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51005444041.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51005444044.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51005444046.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51005447841.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51005447842.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51005447844.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51005447851.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51005447859.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51005568855.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51005568866.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51005568885.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51005568887.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51005568889.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51005568890.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51005568892.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51005568894.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51005568895.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51005577191.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51005582745.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51005587261.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51005605287.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51005605295.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51005605332.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51005621482.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51005663274.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51005663300.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51005663307.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51005663309.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51005663310.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51005663323.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51005675099.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51005675103.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51005675104.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51005675914.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51005676534.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51005676535.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51005676537.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51005676542.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51005676548.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51005677327.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51005677333.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51005677336.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51005677337.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51005684911.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51005684949.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51005705727.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51005705729.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51005705784.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51005710963.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51005711402.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51005711443.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51005711444.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51005711446.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51005711449.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51005715007.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51005715455.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51005719823.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51005719855.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51005719857.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51005719863.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51005719888.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51005719889.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51005719895.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51005719898.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51005719903.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51005719905.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51005724552.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51005724611.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51005724622.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51005724623.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51005724624.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51005724625.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51005724626.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51005724628.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51005741929.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51005742110.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51005745213.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51005745244.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51005745298.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51005746203.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51005746204.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51005746206.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51005746207.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51005746210.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51005749904.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51005757233.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51005757282.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51005757292.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51005757308.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51005757342.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51005763958.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51005763964.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51005763999.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51005764031.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51005764154.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51005764161.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51005806692.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51005806695.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51005806696.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51005806718.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51005806719.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51005806720.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51006008081.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51006008082.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51006008083.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51006008090.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51006008092.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51006008093.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51006008105.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51006008166.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51006008206.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51006248253.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51006311714.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51006327953.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51006327960.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51006328345.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51006328937.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51006328967.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51006329183.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51006329388.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51006332641.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51006334139.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51006334742.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51006334766.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51006334770.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51006334819.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51006334927.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51006335818.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51006349081.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51006349083.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51006349085.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51006350737.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51006387660.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51006387737.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51006387931.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51006387950.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51006387973.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51006388068.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51006388081.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51006388089.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51006389894.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51006389898.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51006392167.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51006401845.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51006401853.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51006401977.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51006414425.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51006414427.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51006414433.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51006414512.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51006414532.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51006414593.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51006414600.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51006414702.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51006414708.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51006414715.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51006414717.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51006414728.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51006438346.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51006466070.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51006502534.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51006502540.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51006554841.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51006555819.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51006555833.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51006555835.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51006556610.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51006556648.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51006556654.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51006556657.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51006556658.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51006556723.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51006556728.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51006556734.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51006556740.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51006556806.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51006556808.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51006556809.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51006556810.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51006556812.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51006556821.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51006556826.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51006556827.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51006556829.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51006556851.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51006556865.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51006557115.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51006557169.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51006557173.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51006557187.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51006557194.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51006557196.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51006557208.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51006557209.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51006557507.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51006619328.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51006619338.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51006619346.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51006619503.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51006619506.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51006619507.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51006619509.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51006619564.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51006619567.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51006619569.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51006619570.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51006619700.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51006619703.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51006619704.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51006619757.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51006619760.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51006619764.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51006619766.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51006619779.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51006619784.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51006619790.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51006619842.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51006619863.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51006619869.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51006620175.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51006620182.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51006620192.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51006620437.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51006647933.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51006647984.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51006733495.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51006828199.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51006828200.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51006828201.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51006856982.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51006857126.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51006857132.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51006857137.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51006857540.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51006912959.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51006912976.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51006912998.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51006913018.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51006913032.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51006913060.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51006913061.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51007103597.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51007103610.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51007103649.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51007103668.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51007103687.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51007225406.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51007231274.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51007231275.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51007231276.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51007231331.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51007231341.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51007231343.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51007231346.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51007231364.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51007231372.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51007339105.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51007339109.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51007339116.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51007339119.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51007339121.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51007339122.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51007339125.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51007339127.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51007339134.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51007339159.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51007339160.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51007339161.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51007339163.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51007339638.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51007391390.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51007433809.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51007579714.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51007579719.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51007579725.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51007846266.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51007846268.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51007846282.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51007846283.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51007846288.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51007846289.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51007846290.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51007846303.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51007846304.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51007846310.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51007846321.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51007846355.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51007846358.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51007846360.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51007846361.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51007846371.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51007846372.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51007846379.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51007846387.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51007846392.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51007846396.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51007846397.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51007846400.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51007846403.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51008030561.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51008030563.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51008042779.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51008042780.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51008042781.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51008042786.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51008042787.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51008099047.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51008099086.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51008099088.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51008099090.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51008099100.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51009008095.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51009447842.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51009453729.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/box/X51009568881.txt
#    creating: /tmp/SROIE2019v02/SROIE2019/test/entities/
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X00016469670.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X00016469671.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51005200931.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51005230605.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51005230616.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51005230621.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51005230648.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51005230657.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51005230659.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51005268275.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51005268408.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51005288570.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51005301666.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51005337867.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51005337877.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51005361906.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51005361908.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51005361912.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51005361923.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51005365187.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51005433518.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51005433543.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51005433548.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51005433556.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51005442322.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51005442334.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51005442343.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51005442366.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51005442375.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51005442382.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51005442388.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51005444040.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51005444041.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51005444044.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51005444046.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51005447841.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51005447842.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51005447844.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51005447851.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51005447859.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51005568855.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51005568866.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51005568885.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51005568887.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51005568889.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51005568890.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51005568892.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51005568894.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51005568895.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51005577191.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51005582745.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51005587261.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51005605287.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51005605295.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51005605332.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51005621482.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51005663274.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51005663300.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51005663307.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51005663309.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51005663310.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51005663323.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51005675099.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51005675103.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51005675104.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51005675914.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51005676534.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51005676535.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51005676537.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51005676542.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51005676548.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51005677327.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51005677333.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51005677336.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51005677337.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51005684911.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51005684949.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51005705727.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51005705729.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51005705784.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51005710963.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51005711402.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51005711443.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51005711444.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51005711446.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51005711449.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51005715007.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51005715455.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51005719823.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51005719855.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51005719857.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51005719863.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51005719888.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51005719889.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51005719895.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51005719898.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51005719903.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51005719905.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51005724552.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51005724611.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51005724622.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51005724623.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51005724624.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51005724625.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51005724626.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51005724628.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51005741929.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51005742110.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51005745213.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51005745244.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51005745298.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51005746203.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51005746204.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51005746206.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51005746207.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51005746210.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51005749904.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51005757233.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51005757282.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51005757292.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51005757308.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51005757342.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51005763958.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51005763964.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51005763999.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51005764031.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51005764154.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51005764161.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51005806692.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51005806695.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51005806696.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51005806718.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51005806719.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51005806720.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51006008081.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51006008082.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51006008083.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51006008090.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51006008092.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51006008093.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51006008105.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51006008166.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51006008206.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51006248253.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51006311714.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51006327953.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51006327960.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51006328345.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51006328937.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51006328967.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51006329183.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51006329388.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51006332641.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51006334139.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51006334742.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51006334766.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51006334770.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51006334819.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51006334927.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51006335818.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51006349081.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51006349083.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51006349085.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51006350737.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51006387660.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51006387737.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51006387931.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51006387950.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51006387973.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51006388068.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51006388081.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51006388089.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51006389894.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51006389898.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51006392167.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51006401845.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51006401853.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51006401977.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51006414425.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51006414427.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51006414433.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51006414512.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51006414532.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51006414593.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51006414600.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51006414702.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51006414708.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51006414715.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51006414717.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51006414728.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51006438346.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51006466070.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51006502534.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51006502540.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51006554841.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51006555819.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51006555833.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51006555835.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51006556610.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51006556648.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51006556654.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51006556657.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51006556658.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51006556723.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51006556728.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51006556734.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51006556740.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51006556806.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51006556808.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51006556809.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51006556810.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51006556812.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51006556821.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51006556826.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51006556827.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51006556829.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51006556851.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51006556865.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51006557115.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51006557169.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51006557173.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51006557187.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51006557194.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51006557196.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51006557208.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51006557209.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51006557507.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51006619328.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51006619338.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51006619346.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51006619503.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51006619506.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51006619507.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51006619509.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51006619564.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51006619567.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51006619569.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51006619570.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51006619700.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51006619703.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51006619704.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51006619757.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51006619760.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51006619764.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51006619766.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51006619779.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51006619784.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51006619790.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51006619842.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51006619863.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51006619869.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51006620175.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51006620182.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51006620192.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51006620437.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51006647933.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51006647984.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51006733495.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51006828199.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51006828200.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51006828201.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51006856982.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51006857126.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51006857132.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51006857137.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51006857540.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51006912959.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51006912976.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51006912998.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51006913018.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51006913032.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51006913060.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51006913061.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51007103597.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51007103610.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51007103649.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51007103668.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51007103687.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51007225406.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51007231274.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51007231275.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51007231276.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51007231331.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51007231341.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51007231343.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51007231346.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51007231364.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51007231372.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51007339105.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51007339109.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51007339116.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51007339119.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51007339121.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51007339122.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51007339125.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51007339127.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51007339134.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51007339159.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51007339160.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51007339161.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51007339163.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51007339638.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51007391390.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51007433809.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51007579714.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51007579719.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51007579725.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51007846266.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51007846268.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51007846282.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51007846283.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51007846288.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51007846289.txt
#   inflating: /tmp/SROIE2019v02/SROIE2019/test/entities/X51007846290.txt
# ...
#   inflating: /tmp/SROIE2019v02/SROIE2019/train/img/X51006619854.jpg
#   inflating: /tmp/SROIE2019v02/SROIE2019/train/img/X51006619862.jpg
#   inflating: /tmp/SROIE2019v02/SROIE2019/train/img/X51006620161.jpg
#   inflating: /tmp/SROIE2019v02/SROIE2019/train/img/X51006620176.jpg
#   inflating: /tmp/SROIE2019v02/SROIE2019/train/img/X51006620181.jpg
#   inflating: /tmp/SROIE2019v02/SROIE2019/train/img/X51006620186.jpg
#   inflating: /tmp/SROIE2019v02/SROIE2019/train/img/X51006620187.jpg
#   inflating: /tmp/SROIE2019v02/SROIE2019/train/img/X51006620189.jpg
#   inflating: /tmp/SROIE2019v02/SROIE2019/train/img/X51006620190.jpg
#   inflating: /tmp/SROIE2019v02/SROIE2019/train/img/X51006620191.jpg
#   inflating: /tmp/SROIE2019v02/SROIE2019/train/img/X51006620414.jpg
#   inflating: /tmp/SROIE2019v02/SROIE2019/train/img/X51006647932.jpg
#   inflating: /tmp/SROIE2019v02/SROIE2019/train/img/X51006679216.jpg
#   inflating: /tmp/SROIE2019v02/SROIE2019/train/img/X51006679222.jpg
#   inflating: /tmp/SROIE2019v02/SROIE2019/train/img/X51006713996.jpg
#   inflating: /tmp/SROIE2019v02/SROIE2019/train/img/X51006714065.jpg
#   inflating: /tmp/SROIE2019v02/SROIE2019/train/img/X51006733494.jpg
#   inflating: /tmp/SROIE2019v02/SROIE2019/train/img/X51006828217.jpg
#   inflating: /tmp/SROIE2019v02/SROIE2019/train/img/X51006856981.jpg
#   inflating: /tmp/SROIE2019v02/SROIE2019/train/img/X51006857071.jpg
#   inflating: /tmp/SROIE2019v02/SROIE2019/train/img/X51006857265.jpg
#   inflating: /tmp/SROIE2019v02/SROIE2019/train/img/X51006857660.jpg
#   inflating: /tmp/SROIE2019v02/SROIE2019/train/img/X51006867435.jpg
#   inflating: /tmp/SROIE2019v02/SROIE2019/train/img/X51006867436.jpg
#   inflating: /tmp/SROIE2019v02/SROIE2019/train/img/X51006882603.jpg
#   inflating: /tmp/SROIE2019v02/SROIE2019/train/img/X51006912960.jpg
#   inflating: /tmp/SROIE2019v02/SROIE2019/train/img/X51006912972.jpg
#   inflating: /tmp/SROIE2019v02/SROIE2019/train/img/X51006912974.jpg
#   inflating: /tmp/SROIE2019v02/SROIE2019/train/img/X51006913007.jpg
#   inflating: /tmp/SROIE2019v02/SROIE2019/train/img/X51006913019.jpg
#   inflating: /tmp/SROIE2019v02/SROIE2019/train/img/X51006913023.jpg
#   inflating: /tmp/SROIE2019v02/SROIE2019/train/img/X51006913024.jpg
#   inflating: /tmp/SROIE2019v02/SROIE2019/train/img/X51006913028.jpg
#   inflating: /tmp/SROIE2019v02/SROIE2019/train/img/X51006913030.jpg
#   inflating: /tmp/SROIE2019v02/SROIE2019/train/img/X51006913031.jpg
#   inflating: /tmp/SROIE2019v02/SROIE2019/train/img/X51006913051.jpg
#   inflating: /tmp/SROIE2019v02/SROIE2019/train/img/X51006913054.jpg
#   inflating: /tmp/SROIE2019v02/SROIE2019/train/img/X51006913055.jpg
#   inflating: /tmp/SROIE2019v02/SROIE2019/train/img/X51006913059.jpg
#   inflating: /tmp/SROIE2019v02/SROIE2019/train/img/X51006913068.jpg
#   inflating: /tmp/SROIE2019v02/SROIE2019/train/img/X51006913070.jpg
#   inflating: /tmp/SROIE2019v02/SROIE2019/train/img/X51006913073.jpg
#   inflating: /tmp/SROIE2019v02/SROIE2019/train/img/X51006913074.jpg
#   inflating: /tmp/SROIE2019v02/SROIE2019/train/img/X51007103578.jpg
#   inflating: /tmp/SROIE2019v02/SROIE2019/train/img/X51007103599.jpg
#   inflating: /tmp/SROIE2019v02/SROIE2019/train/img/X51007103639.jpg
#   inflating: /tmp/SROIE2019v02/SROIE2019/train/img/X51007103641.jpg
#   inflating: /tmp/SROIE2019v02/SROIE2019/train/img/X51007103643.jpg
#   inflating: /tmp/SROIE2019v02/SROIE2019/train/img/X51007103675.jpg
#   inflating: /tmp/SROIE2019v02/SROIE2019/train/img/X51007103681.jpg
#   inflating: /tmp/SROIE2019v02/SROIE2019/train/img/X51007103688.jpg
#   inflating: /tmp/SROIE2019v02/SROIE2019/train/img/X51007103691.jpg
#   inflating: /tmp/SROIE2019v02/SROIE2019/train/img/X51007103692.jpg
#   inflating: /tmp/SROIE2019v02/SROIE2019/train/img/X51007103702.jpg
#   inflating: /tmp/SROIE2019v02/SROIE2019/train/img/X51007135037.jpg
#   inflating: /tmp/SROIE2019v02/SROIE2019/train/img/X51007135247.jpg
#   inflating: /tmp/SROIE2019v02/SROIE2019/train/img/X51007225398.jpg
#   inflating: /tmp/SROIE2019v02/SROIE2019/train/img/X51007225399.jpg
#   inflating: /tmp/SROIE2019v02/SROIE2019/train/img/X51007225417.jpg
#   inflating: /tmp/SROIE2019v02/SROIE2019/train/img/X51007225442.jpg
#   inflating: /tmp/SROIE2019v02/SROIE2019/train/img/X51007228448.jpg
#   inflating: /tmp/SROIE2019v02/SROIE2019/train/img/X51007231336.jpg
#   inflating: /tmp/SROIE2019v02/SROIE2019/train/img/X51007231338.jpg
#   inflating: /tmp/SROIE2019v02/SROIE2019/train/img/X51007231344.jpg
#   inflating: /tmp/SROIE2019v02/SROIE2019/train/img/X51007231361.jpg
#   inflating: /tmp/SROIE2019v02/SROIE2019/train/img/X51007231365.jpg
#   inflating: /tmp/SROIE2019v02/SROIE2019/train/img/X51007231370.jpg
#   inflating: /tmp/SROIE2019v02/SROIE2019/train/img/X51007231374.jpg
#   inflating: /tmp/SROIE2019v02/SROIE2019/train/img/X51007262315.jpg
#   inflating: /tmp/SROIE2019v02/SROIE2019/train/img/X51007262328.jpg
#   inflating: /tmp/SROIE2019v02/SROIE2019/train/img/X51007262330.jpg
#   inflating: /tmp/SROIE2019v02/SROIE2019/train/img/X51007339094.jpg
#   inflating: /tmp/SROIE2019v02/SROIE2019/train/img/X51007339095.jpg
#   inflating: /tmp/SROIE2019v02/SROIE2019/train/img/X51007339097.jpg
#   inflating: /tmp/SROIE2019v02/SROIE2019/train/img/X51007339098.jpg
#   inflating: /tmp/SROIE2019v02/SROIE2019/train/img/X51007339100.jpg
#   inflating: /tmp/SROIE2019v02/SROIE2019/train/img/X51007339106.jpg
#   inflating: /tmp/SROIE2019v02/SROIE2019/train/img/X51007339107.jpg
#   inflating: /tmp/SROIE2019v02/SROIE2019/train/img/X51007339110.jpg
#   inflating: /tmp/SROIE2019v02/SROIE2019/train/img/X51007339111.jpg
#   inflating: /tmp/SROIE2019v02/SROIE2019/train/img/X51007339112.jpg
#   inflating: /tmp/SROIE2019v02/SROIE2019/train/img/X51007339113.jpg
#   inflating: /tmp/SROIE2019v02/SROIE2019/train/img/X51007339114.jpg
#   inflating: /tmp/SROIE2019v02/SROIE2019/train/img/X51007339115.jpg
#   inflating: /tmp/SROIE2019v02/SROIE2019/train/img/X51007339117.jpg
#   inflating: /tmp/SROIE2019v02/SROIE2019/train/img/X51007339118.jpg
#   inflating: /tmp/SROIE2019v02/SROIE2019/train/img/X51007339120.jpg
#   inflating: /tmp/SROIE2019v02/SROIE2019/train/img/X51007339126.jpg
#   inflating: /tmp/SROIE2019v02/SROIE2019/train/img/X51007339130.jpg
#   inflating: /tmp/SROIE2019v02/SROIE2019/train/img/X51007339131.jpg
#   inflating: /tmp/SROIE2019v02/SROIE2019/train/img/X51007339132.jpg
#   inflating: /tmp/SROIE2019v02/SROIE2019/train/img/X51007339133.jpg
#   inflating: /tmp/SROIE2019v02/SROIE2019/train/img/X51007339135.jpg
#   inflating: /tmp/SROIE2019v02/SROIE2019/train/img/X51007339136.jpg
#   inflating: /tmp/SROIE2019v02/SROIE2019/train/img/X51007339139.jpg
#   inflating: /tmp/SROIE2019v02/SROIE2019/train/img/X51007339146.jpg
#   inflating: /tmp/SROIE2019v02/SROIE2019/train/img/X51007339150.jpg
#   inflating: /tmp/SROIE2019v02/SROIE2019/train/img/X51007339151.jpg
#   inflating: /tmp/SROIE2019v02/SROIE2019/train/img/X51007339152.jpg
#   inflating: /tmp/SROIE2019v02/SROIE2019/train/img/X51007339156.jpg
#   inflating: /tmp/SROIE2019v02/SROIE2019/train/img/X51007339157.jpg
#   inflating: /tmp/SROIE2019v02/SROIE2019/train/img/X51007339158.jpg
#   inflating: /tmp/SROIE2019v02/SROIE2019/train/img/X51007339162.jpg
#   inflating: /tmp/SROIE2019v02/SROIE2019/train/img/X51007339164.jpg
#   inflating: /tmp/SROIE2019v02/SROIE2019/train/img/X51007339165.jpg
#   inflating: /tmp/SROIE2019v02/SROIE2019/train/img/X51007339166.jpg
#   inflating: /tmp/SROIE2019v02/SROIE2019/train/img/X51007339167.jpg
#   inflating: /tmp/SROIE2019v02/SROIE2019/train/img/X51007339639.jpg
#   inflating: /tmp/SROIE2019v02/SROIE2019/train/img/X51007339642.jpg
#   inflating: /tmp/SROIE2019v02/SROIE2019/train/img/X51007339643.jpg
#   inflating: /tmp/SROIE2019v02/SROIE2019/train/img/X51007339647.jpg
#   inflating: /tmp/SROIE2019v02/SROIE2019/train/img/X51007339648.jpg
#   inflating: /tmp/SROIE2019v02/SROIE2019/train/img/X51007339650.jpg
#   inflating: /tmp/SROIE2019v02/SROIE2019/train/img/X51007339651.jpg
#   inflating: /tmp/SROIE2019v02/SROIE2019/train/img/X51007339653.jpg
#   inflating: /tmp/SROIE2019v02/SROIE2019/train/img/X51007339656.jpg
#   inflating: /tmp/SROIE2019v02/SROIE2019/train/img/X51007339657.jpg
#   inflating: /tmp/SROIE2019v02/SROIE2019/train/img/X51007339658.jpg
#   inflating: /tmp/SROIE2019v02/SROIE2019/train/img/X51007391372.jpg
#   inflating: /tmp/SROIE2019v02/SROIE2019/train/img/X51007419197.jpg
#   inflating: /tmp/SROIE2019v02/SROIE2019/train/img/X51007579726.jpg
#   inflating: /tmp/SROIE2019v02/SROIE2019/train/img/X51007843145.jpg
#   inflating: /tmp/SROIE2019v02/SROIE2019/train/img/X51007846269.jpg
#   inflating: /tmp/SROIE2019v02/SROIE2019/train/img/X51007846270.jpg
#   inflating: /tmp/SROIE2019v02/SROIE2019/train/img/X51007846286.jpg
#   inflating: /tmp/SROIE2019v02/SROIE2019/train/img/X51007846301.jpg
#   inflating: /tmp/SROIE2019v02/SROIE2019/train/img/X51007846302.jpg
#   inflating: /tmp/SROIE2019v02/SROIE2019/train/img/X51007846305.jpg
#   inflating: /tmp/SROIE2019v02/SROIE2019/train/img/X51007846307.jpg
#   inflating: /tmp/SROIE2019v02/SROIE2019/train/img/X51007846309.jpg
#   inflating: /tmp/SROIE2019v02/SROIE2019/train/img/X51007846325.jpg
#   inflating: /tmp/SROIE2019v02/SROIE2019/train/img/X51007846326.jpg
#   inflating: /tmp/SROIE2019v02/SROIE2019/train/img/X51007846350.jpg
#   inflating: /tmp/SROIE2019v02/SROIE2019/train/img/X51007846353.jpg
#   inflating: /tmp/SROIE2019v02/SROIE2019/train/img/X51007846357.jpg
#   inflating: /tmp/SROIE2019v02/SROIE2019/train/img/X51007846366.jpg
#   inflating: /tmp/SROIE2019v02/SROIE2019/train/img/X51007846368.jpg
#   inflating: /tmp/SROIE2019v02/SROIE2019/train/img/X51007846370.jpg
#   inflating: /tmp/SROIE2019v02/SROIE2019/train/img/X51007846388.jpg
#   inflating: /tmp/SROIE2019v02/SROIE2019/train/img/X51007846391.jpg
#   inflating: /tmp/SROIE2019v02/SROIE2019/train/img/X51007846393.jpg
#   inflating: /tmp/SROIE2019v02/SROIE2019/train/img/X51007846395.jpg
#   inflating: /tmp/SROIE2019v02/SROIE2019/train/img/X51007846398.jpg
#   inflating: /tmp/SROIE2019v02/SROIE2019/train/img/X51007846410.jpg
#   inflating: /tmp/SROIE2019v02/SROIE2019/train/img/X51007846412.jpg
#   inflating: /tmp/SROIE2019v02/SROIE2019/train/img/X51007846451.jpg
#   inflating: /tmp/SROIE2019v02/SROIE2019/train/img/X51008030560.jpg
#   inflating: /tmp/SROIE2019v02/SROIE2019/train/img/X51008030565.jpg
#   inflating: /tmp/SROIE2019v02/SROIE2019/train/img/X51008030566.jpg
#   inflating: /tmp/SROIE2019v02/SROIE2019/train/img/X51008042777.jpg
#   inflating: /tmp/SROIE2019v02/SROIE2019/train/img/X51008042778.jpg
#   inflating: /tmp/SROIE2019v02/SROIE2019/train/img/X51008042782.jpg
#   inflating: /tmp/SROIE2019v02/SROIE2019/train/img/X51008042783.jpg
#   inflating: /tmp/SROIE2019v02/SROIE2019/train/img/X51008042791.jpg
#   inflating: /tmp/SROIE2019v02/SROIE2019/train/img/X51008042792.jpg
#   inflating: /tmp/SROIE2019v02/SROIE2019/train/img/X51008042793.jpg
#   inflating: /tmp/SROIE2019v02/SROIE2019/train/img/X51008063849.jpg
#   inflating: /tmp/SROIE2019v02/SROIE2019/train/img/X51008064061.jpg
#   inflating: /tmp/SROIE2019v02/SROIE2019/train/img/X51008099041.jpg
#   inflating: /tmp/SROIE2019v02/SROIE2019/train/img/X51008099043.jpg
#   inflating: /tmp/SROIE2019v02/SROIE2019/train/img/X51008099044.jpg
#   inflating: /tmp/SROIE2019v02/SROIE2019/train/img/X51008099046.jpg
#   inflating: /tmp/SROIE2019v02/SROIE2019/train/img/X51008099048.jpg
#   inflating: /tmp/SROIE2019v02/SROIE2019/train/img/X51008099049.jpg
#   inflating: /tmp/SROIE2019v02/SROIE2019/train/img/X51008099054.jpg
#   inflating: /tmp/SROIE2019v02/SROIE2019/train/img/X51008099071.jpg
#   inflating: /tmp/SROIE2019v02/SROIE2019/train/img/X51008099073.jpg
#   inflating: /tmp/SROIE2019v02/SROIE2019/train/img/X51008099081.jpg
#   inflating: /tmp/SROIE2019v02/SROIE2019/train/img/X51008099083.jpg
#   inflating: /tmp/SROIE2019v02/SROIE2019/train/img/X51008099084.jpg
#   inflating: /tmp/SROIE2019v02/SROIE2019/train/img/X51008099085.jpg
#   inflating: /tmp/SROIE2019v02/SROIE2019/train/img/X51008099087.jpg
#   inflating: /tmp/SROIE2019v02/SROIE2019/train/img/X51008099089.jpg
#   inflating: /tmp/SROIE2019v02/SROIE2019/train/img/X51008099102.jpg
#   inflating: /tmp/SROIE2019v02/SROIE2019/train/img/X51008114216.jpg
#   inflating: /tmp/SROIE2019v02/SROIE2019/train/img/X51008114217.jpg
#   inflating: /tmp/SROIE2019v02/SROIE2019/train/img/X51008114260.jpg
#   inflating: /tmp/SROIE2019v02/SROIE2019/train/img/X51008114262.jpg
#   inflating: /tmp/SROIE2019v02/SROIE2019/train/img/X51008114266.jpg
#   inflating: /tmp/SROIE2019v02/SROIE2019/train/img/X51008114281.jpg
#   inflating: /tmp/SROIE2019v02/SROIE2019/train/img/X51008114282.jpg
#   inflating: /tmp/SROIE2019v02/SROIE2019/train/img/X51008114283.jpg
#   inflating: /tmp/SROIE2019v02/SROIE2019/train/img/X51008114284.jpg
#   inflating: /tmp/SROIE2019v02/SROIE2019/train/img/X51008114321.jpg
#   inflating: /tmp/SROIE2019v02/SROIE2019/train/img/X51008122920.jpg
#   inflating: /tmp/SROIE2019v02/SROIE2019/train/img/X51008123446.jpg
#   inflating: /tmp/SROIE2019v02/SROIE2019/train/img/X51008123447.jpg
#   inflating: /tmp/SROIE2019v02/SROIE2019/train/img/X51008123450.jpg
#   inflating: /tmp/SROIE2019v02/SROIE2019/train/img/X51008123451.jpg
#   inflating: /tmp/SROIE2019v02/SROIE2019/train/img/X51008123476.jpg
#   inflating: /tmp/SROIE2019v02/SROIE2019/train/img/X51008123580.jpg
#   inflating: /tmp/SROIE2019v02/SROIE2019/train/img/X51008123586.jpg
#   inflating: /tmp/SROIE2019v02/SROIE2019/train/img/X51008123599.jpg
#   inflating: /tmp/SROIE2019v02/SROIE2019/train/img/X51008123604.jpg
#   inflating: /tmp/SROIE2019v02/SROIE2019/train/img/X51008128052.jpg
#   inflating: /tmp/SROIE2019v02/SROIE2019/train/img/X51008128062.jpg
#   inflating: /tmp/SROIE2019v02/SROIE2019/train/img/X51008128065.jpg
#   inflating: /tmp/SROIE2019v02/SROIE2019/train/img/X51008142005.jpg
#   inflating: /tmp/SROIE2019v02/SROIE2019/train/img/X51008142030.jpg
#   inflating: /tmp/SROIE2019v02/SROIE2019/train/img/X51008142031.jpg
#   inflating: /tmp/SROIE2019v02/SROIE2019/train/img/X51008142032.jpg
#   inflating: /tmp/SROIE2019v02/SROIE2019/train/img/X51008142033.jpg
#   inflating: /tmp/SROIE2019v02/SROIE2019/train/img/X51008142034.jpg
#   inflating: /tmp/SROIE2019v02/SROIE2019/train/img/X51008142038.jpg
#   inflating: /tmp/SROIE2019v02/SROIE2019/train/img/X51008142058.jpg
#   inflating: /tmp/SROIE2019v02/SROIE2019/train/img/X51008142059.jpg
#   inflating: /tmp/SROIE2019v02/SROIE2019/train/img/X51008142060.jpg
#   inflating: /tmp/SROIE2019v02/SROIE2019/train/img/X51008142061.jpg
#   inflating: /tmp/SROIE2019v02/SROIE2019/train/img/X51008142062.jpg
#   inflating: /tmp/SROIE2019v02/SROIE2019/train/img/X51008142063.jpg
#   inflating: /tmp/SROIE2019v02/SROIE2019/train/img/X51008142065.jpg
#   inflating: /tmp/SROIE2019v02/SROIE2019/train/img/X51008142068.jpg
#   inflating: /tmp/SROIE2019v02/SROIE2019/train/img/X51008145450.jpg
#   inflating: /tmp/SROIE2019v02/SROIE2019/train/img/X51008145504.jpg
#   inflating: /tmp/SROIE2019v02/SROIE2019/train/img/X51008145505.jpg
#   inflating: /tmp/SROIE2019v02/SROIE2019/train/img/X51008164420.jpg
#   inflating: /tmp/SROIE2019v02/SROIE2019/train/img/X51008164510.jpg
#   inflating: /tmp/SROIE2019v02/SROIE2019/train/img/X51008164524.jpg
#   inflating: /tmp/SROIE2019v02/SROIE2019/train/img/X51008164525.jpg
#   inflating: /tmp/SROIE2019v02/SROIE2019/train/img/X51008164969.jpg
#   inflating: /tmp/SROIE2019v02/SROIE2019/train/img/X51008164991.jpg
#   inflating: /tmp/SROIE2019v02/SROIE2019/train/img/X51008164992.jpg
#   inflating: /tmp/SROIE2019v02/SROIE2019/train/img/X51008164996.jpg
#   inflating: /tmp/SROIE2019v02/SROIE2019/train/img/X51008164997.jpg
#   inflating: /tmp/SROIE2019v02/SROIE2019/train/img/X51008164998.jpg
#   inflating: /tmp/SROIE2019v02/SROIE2019/train/img/X51008164999.jpg
#   inflating: /tmp/SROIE2019v02/SROIE2019/train/img/X51009453801.jpg
#   inflating: /tmp/SROIE2019v02/SROIE2019/train/img/X51009453804.jpg

# %% [markdown]
# ##Importar Librerias

# %%
# Instale la versión más reciente de gensim.
# De lo contrario, puede recibir el siguiente error al ejecutar naw.WordEmbsAug():
# El objeto 'Word2VecKeyedVectors' no tiene atributo 'index_to_key'
# see: https://stackoverflow.com/questions/71032760/word2veckeyedvectors-object-has-no-attribute-index-to-key
# !pip install --upgrade gensim --quiet

# %%
# Importar gensim.
# Nota: deberá reiniciar el tiempo de ejecución para importar la versión más reciente de gensim
import gensim
print(gensim.__version__)
# Out:
# 4.3.2

# %%
# Instale el tokenizador que necesita el modelo de traducción inversa
# !pip install sacremoses --quiet
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 897.5/897.5 kB 8.3 MB/s eta 0:00:00

# %%
# Install the tokenizer
import sacremoses

# %%
# Install the nlpaug module
# !pip install nlpaug --quiet
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.5/410.5 kB 6.3 MB/s eta 0:00:00

# %%
# Importar el módulo nlpaug y sus métodos
import nlpaug.augmenter.word as naw
import nlpaug.flow as nafc
from nlpaug.util import Action

# %%
# Install Huggingface Transformers
! pip install transformers[sentencepiece] --quiet
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 6.3 MB/s eta 0:00:00

# %%
# Install datasets
! pip install datasets --quiet
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 507.1/507.1 kB 6.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.3/115.3 kB 6.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 8.6 MB/s eta 0:00:00

# %%
! pip install accelerate -U
# Out:
# Collecting accelerate
#   Downloading accelerate-0.25.0-py3-none-any.whl (265 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 265.7/265.7 kB 5.5 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from accelerate) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from accelerate) (23.2)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from accelerate) (5.9.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from accelerate) (6.0.1)
# Requirement already satisfied: torch>=1.10.0 in /usr/local/lib/python3.10/dist-packages (from accelerate) (2.1.0+cu121)
# Requirement already satisfied: huggingface-hub in /usr/local/lib/python3.10/dist-packages (from accelerate) (0.20.1)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from accelerate) (0.4.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (3.13.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (3.1.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (2023.6.0)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (2.1.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->accelerate) (2.31.0)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->accelerate) (4.66.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.10.0->accelerate) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->accelerate) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->accelerate) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->accelerate) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->accelerate) (2023.11.17)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.10.0->accelerate) (1.3.0)
# Installing collected packages: accelerate
# Successfully installed accelerate-0.25.0

# %%
# Import other modules
import nltk
nltk.download('wordnet')
nltk.download('stopwords')
nltk.download('omw-1.4')
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from datasets import DatasetDict, Dataset
from transformers import AutoTokenizer, AutoModelForSequenceClassification
from transformers import Trainer, TrainingArguments
from transformers import Trainer
from sklearn.metrics import accuracy_score, f1_score
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import gc
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...

# %%
import json
import random
import re
import joblib
from tqdm import tqdm

import spacy.cli
from spacy import displacy
from spacy.util import minibatch, compounding
from spacy.training import Example
from spacy.scorer import Scorer
import pathlib

from spacy.training import offsets_to_biluo_tags
from spacy.tokenizer import Tokenizer

# %% [markdown]
# ## Crear Modelo NER

# %%
nlp = spacy.blank("en")
ner = nlp.create_pipe("ner")
nlp.add_pipe("ner")

# %%
def parse(line):
    fields = line.strip().split(",")
    if len(fields) == 9:
        return fields
    else:
        return fields[:8] + [",".join(fields[8:])]

def build_text(data):
    text = " ".join(data.text)
    text = text.replace("  "," ")
    return text

def entidades_total_prueba (ruta,archivo):
  #ruta ='/tmp/SROIE2019v02/SROIE2019/train/'
  #archivo = 'X51007419197.txt'

  print(archivo)
  with open(ruta + "box/" + archivo, encoding='utf-8', errors='ignore') as f:
    ocr = f.readlines()
  data = pd.DataFrame(
    list(map(parse, ocr)),
    columns=[*(f"coor{i}" for i in range(8)), "text"]
    )
  data=data.dropna()
  #print("data",data)
  texto = build_text(data)
  #print("texto",texto)

  with open(ruta + "entities/" + archivo, encoding='utf-8') as f:
    entities = json.load(f)
  #print("entities=",entities)
  #print("type_entities=",type(entities))
  entidades = []
  for name, ent_text in entities.items():
    if len(ent_text)==0:
      continue
    else:
      ent_text=ent_text.translate(str.maketrans({"-":  r"\-",
                                                  "]":  r"\]",
                                                  "\\": r"\\",
                                                  "^":  r"\^",
                                                  "$":  r"\$",
                                                  "*":  r"\*",
                                                  ".":  r"\.",
                                                  "(":  r"\(",
                                                  ")":  r"\)" }))
    #print("ent_text=",ent_text)
    matches = re.finditer(ent_text, texto)
    local_ent = map(lambda match: (*match.span(), name), matches)
    entidades.extend(list(local_ent))
  entidades.sort()

  label_iden = {"total": False,
                "date": False,
                "address": False,
                "company": False
      }
  #print("entidades",entidades)
  entidades_n = []
  for ent in reversed(entidades):
    #print("ent=",ent)
    label= ent[2]
    if label_iden[label]==False:
      label_iden[label]=True
      entidades_n.append(ent)
    #print("entidades_n=",entidades_n)
  entidades_n.sort()
  #print("entidades_n",entidades_n)
  texto_faltantes=[]
  i=0
  pos_ini = 0
  pos_fin = 0

  for ent in entidades_n:
    if (i == 0) & (ent[0] > 0):
      pos_ini = 0
      pos_fin = ent[0]-1
      texto_faltantes.append((pos_ini,pos_fin,texto[pos_ini:pos_fin]))
      #print("if 1 ent=",ent,"pos_ini=",pos_ini,"pos_fin=",pos_fin,"texto_f=",texto[pos_ini:pos_fin])
    if i < len(entidades_n)-1:
      if ent[1]+1 != entidades_n[i+1][0]:
        pos_ini = entidades_n[i][1]+1
        pos_fin = entidades_n[i+1][0]-1
        texto_faltantes.append((pos_ini,pos_fin,texto[pos_ini:pos_fin]))
        #print("if 2 ent=",ent,"pos_ini=",pos_ini,"pos_fin=",pos_fin,"texto_f=",texto[pos_ini:pos_fin])
    i+=1

  if (pos_fin < len(texto)-1) & (entidades_n[-1][1] < len(texto)-1):
    if pos_fin > entidades_n[-1][1]:
      pos_ini = pos_fin + 1
      pos_fin = len(texto)
    else:
      pos_ini = entidades_n[-1][1]+1
      pos_fin = len(texto)
    texto_faltantes.append((pos_ini,pos_fin,texto[pos_ini:pos_fin]))
    #print("if 3 ent=",ent, "pos_ini=",pos_ini,"pos_fin=",pos_fin,"texto_f=",texto[pos_ini:pos_fin])
  entidades_faltantes = []
  #print("texto_faltantes",texto_faltantes)
  for texto_fa in texto_faltantes:
    pos_ini,pos_fin,texto_f = texto_fa
    #print("pos_ini=",pos_ini," pos_fin=",pos_fin," texto_f=",texto_f)
    #tonkens = tokenizer(texto_f)
    tonkens = texto_f.split(' ')
    pos_ini_t = pos_ini
    for token in tonkens:
      pos_fin_t = pos_ini_t + len(token)
      #print("pos_ini_t=",pos_ini_t,"pos_fin_t=",pos_fin_t,"token=",token,"textoP=",texto[pos_ini_t:pos_fin_t])
      entidades_faltantes.append((pos_ini_t,pos_fin_t,'O'))
      pos_ini_t = pos_fin_t + 1
  #print("entidades_faltantes",entidades_faltantes)
  entidades_final=entidades_n + entidades_faltantes
  entidades_final.sort()
  spacy.training.offsets_to_biluo_tags(nlp.make_doc(texto), entidades_final)
  tags = offsets_to_biluo_tags(nlp.make_doc(texto), entidades_final)
  #print("tags=",tags)
  #doc_p = nlp.make_doc(texto)
  #for tok in doc_p:
   #print("tok=",tok)
  entidades_final=dict(entities=entidades_final)
  entidades_final= (texto,entidades_final,entidades_n)
  #print("entidades_final=",entidades_final)
  return(entidades_final)

# %%
def SacarTextoArchivo (ruta,archivo):
  #ruta ='/tmp/SROIE2019v02/SROIE2019/train/'
  #archivo = 'X51007419197.txt'

  print(archivo)
  with open(ruta + "box/" + archivo, encoding='utf-8', errors='ignore') as f:
    ocr = f.readlines()
  data = pd.DataFrame(
    list(map(parse, ocr)),
    columns=[*(f"coor{i}" for i in range(8)), "text"]
    )
  data=data.dropna()
  #print("data",data)
  texto = build_text(data)
  #print("texto",texto)
  texto_final = (texto,archivo)
  return(texto_final)

# %% [markdown]
# ##Armar Dataset

# %%
data_dir = "/tmp/SROIE2019v02/SROIE2019/train/box"
data_dir = pathlib.Path(data_dir)
box_count = len(list(data_dir.glob('**/*.txt')))
print(box_count)
l_box=list(data_dir.glob('**/*.txt'))

data_dir = "/tmp/SROIE2019v02/SROIE2019/test/box"
data_dir = pathlib.Path(data_dir)
box_count_test = len(list(data_dir.glob('**/*.txt')))
print(box_count_test)
l_box_test=list(data_dir.glob('**/*.txt'))
# Out:
# 626
# 347

# %%
l_box_archivo= list(map(lambda cadena: str(cadena)[-16:], l_box))
l_box_test_archivo= list(map(lambda cadena: str(cadena)[-16:], l_box_test))

# %%
textos_nerd = joblib.Parallel(n_jobs=-1)(joblib.delayed(SacarTextoArchivo)('/tmp/SROIE2019v02/SROIE2019/train/',archivo) for archivo in tqdm(l_box_archivo))
# Out:
# 100%|██████████| 626/626 [00:02<00:00, 217.77it/s]

# %%
textos_nerd_test = joblib.Parallel(n_jobs=-1)(joblib.delayed(SacarTextoArchivo)('/tmp/SROIE2019v02/SROIE2019/test/',archivo) for archivo in tqdm(l_box_test_archivo))
# Out:
# 100%|██████████| 347/347 [00:00<00:00, 494.90it/s]

# %%
df = pd.DataFrame(textos_nerd_test, columns=['text', 'archivo'])
test_df = df[['text', 'archivo']]
#print(test_df)
df = pd.DataFrame(textos_nerd, columns=['text',  'archivo'])
train_df = df[['text', 'archivo']]
#print(train_df)

# %%
# Convert the three DataFrames to three Datasets (Aparche Arrow format)
# Convierta los tres DataFrames de datos en tres conjuntos de datos (formato de flecha de Apache) (Aparche Arrow format)

dset_test = Dataset.from_pandas( test_df)
dset_train = Dataset.from_pandas(train_df)

# %%
# Gather train, val, and test Datasets to have a single DatasetDict, which can be manipulated together
# Reúna conjuntos de datos de train, val, y test para tener un solo DatasetDict, que se puede manipular juntos
sroie = DatasetDict({
  'train': dset_train,
  'test': dset_test})
# Dataset.from_pandas will add an index column, which can be removed
# Dataset.from_pandas agregará una columna de índice, que se puede eliminar

# %%
sroie
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['text', 'archivo'],
#         num_rows: 626
#     })
#     test: Dataset({
#         features: ['text', 'archivo'],
#         num_rows: 347
#     })
# })

# %%
# Use GPU (cuda) if available
import torch
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# ## Initiate three alternative text augmentation strategies

# %%
# Initiate the synonym augmentation - # Iniciar el aumento de sinónimos
aug_syn = naw.SynonymAug(
  aug_src = 'wordnet',
  aug_max = 3)

# %%
augmented_sroie = []
augmented_sorie_archivo = []
for i in train_df.index:
    lst_augment = aug_syn.augment(train_df['text'].loc[i], n = 1)
    for augment in lst_augment:
        augmented_sroie.append(augment)
        augmented_sorie_archivo.append(train_df['archivo'].loc[i])

  # Zip the two lists into a list of tuples -  Comprima las dos listas en una lista de tuplas
augmented_sorie_textarchivo = list(zip(augmented_sroie, augmented_sorie_archivo))

df = pd.DataFrame(augmented_sorie_textarchivo, columns=['text', 'archivo'])
df_augmented = df[['text', 'archivo']]
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.

# %%
train_df_augmented = pd.concat([train_df, df_augmented], axis = 0)

# %%
train_df_augmented.describe()
# Out:
#                                                      text           archivo
# count                                                1252              1252
# unique                                               1250               626
# top     B & BEST RESTAURANT (001610235-P) GST NO. : 00...  X51007339642.txt
# freq                                                    2                 2

# %%
# Initiate the contextual word embeddings (BERT, DistilBERT, RoBERTA or XLNet) augmentation
#Inicie el aumento de incrustaciones de palabras contextuales (BERT, DistilBERT, RoBERTA o XLNet)
aug_emb = naw.ContextualWordEmbsAug(
  # Other models include 'distilbert-base-uncased', 'roberta-base', etc.
  # Otros modelos incluyen 'distilbert-base-uncased', 'roberta-base', etc.
  model_path = 'distilbert-base-uncased',
  # You can also choose "insert" - También puede elegir "insertar"
  action = "substitute",
  # Use GPU
  device = 'cuda'
  )
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:72: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/28.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/483 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/268M [00:00<?, ?B/s]

# %%
# Initiate the back translation augmentation - Iniciar el aumento de traducción inversa
aug_bt = naw.BackTranslationAug(
  # Translate English to German -  Traducir inglés a alemán
  from_model_name = 'facebook/wmt19-en-de',
  # Translate German back to English - Traducir alemán de nuevo a inglés
  to_model_name = 'facebook/wmt19-de-en',
  # Use GPU
  device = 'cuda')
# Out:
# config.json:   0%|          | 0.00/825 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/1.08G [00:00<?, ?B/s]
# Some weights of FSMTForConditionalGeneration were not initialized from the model checkpoint at facebook/wmt19-en-de and are newly initialized: ['model.decoder.embed_positions.weight', 'model.encoder.embed_positions.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# generation_config.json:   0%|          | 0.00/235 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/825 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.08G [00:00<?, ?B/s]
# Some weights of FSMTForConditionalGeneration were not initialized from the model checkpoint at facebook/wmt19-de-en and are newly initialized: ['model.decoder.embed_positions.weight', 'model.encoder.embed_positions.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# generation_config.json:   0%|          | 0.00/260 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/67.0 [00:00<?, ?B/s]
# vocab-src.json:   0%|          | 0.00/849k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/315k [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/67.0 [00:00<?, ?B/s]
# vocab-src.json:   0%|          | 0.00/849k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/315k [00:00<?, ?B/s]

# %%
# Create a function to evaluate text augmentation on model performance on test set
# Cree una función para evaluar el aumento de texto en el rendimiento del modelo en el conjunto de prueba
def evaluate_aug(aug_strategy, n, train_df, dset_test):

  # Create two lists to store augmented tweets and their correponding labels
  # Cree dos listas para almacenar tweets aumentados y sus etiquetas correspondientes
  augmented_text = []
  augmented_archivo = []

  # Loop through the train set to create augmented tweets
  # Note: We create n augmented tweets per original tweet.
  # Recorre el juego de train para crear tweets aumentados
  # Nota: Creamos n tweets aumentados por tweet original.
  for i in train_df.index:
    if aug_strategy == 'synonym':
      lst_augment = aug_syn.augment(train_df['text'].loc[i], n = n)
    elif aug_strategy == 'embedding':
      lst_augment = aug_emb.augment(train_df['text'].loc[i], n = n)
    else:
      lst_augment = aug_bt.augment(train_df['text'].loc[i], n = n)
    for augment in lst_augment:
      augmented_text.append(augment)
      augmented_archivo.append(train_df['archivo'].loc[i])

  # Zip the two lists into a list of tuples -  Comprima las dos listas en una lista de tuplas
  augmented_textarchivo = list(zip(augmented_text, augmented_archivo))

  # Convert the list of tuples to a Pandas Dataframe. -  Convierte la lista de tuplas en un marco de datos de Pandas.
  df_augmented_text = pd.DataFrame(
    augmented_textarchivo, columns = ['text', 'archivo'])

  # Vertically concat the train set with the augmented texts
  # Conectar verticalmente el set de train con los textos aumentados
##train_df_augmented = pd.concat([train_df, df_augmented_text], axis = 0)
  # Convert the DataFrame to a Dataset (Aparche Arrow format)
  # Convertir el marco de datos en un conjunto de datos
##dset_train_augmented = Dataset.from_pandas(train_df_augmented)
 ##dset_train_augmented = dset_train_augmented.remove_columns(["__index_level_0__"])
  # Gather train, val, and test Datasets to have a single DatasetDict,
  # which can be manipulated together
  # Reúna conjuntos de datos de train, val, y test para tener un solo DatasetDict,
  # que se pueden manipular juntos
##text_augmented = DatasetDict({
##    'train': dset_train_augmented,
##    'test': dset_test})

  return(df_augmented_text)

# %%
# Evaluar el aumento de texto sinónimo
DataFrame_synonym = evaluate_aug(
  aug_strategy = 'synonym',
  n = 1,
  train_df = train_df,
  dset_test = dset_test)
print(DataFrame_synonym)
# Out:
#                                                   text           archivo
# 0    AIK HUAT HARDWARE ENTERPRISE (SETIA ALAM) SDN ...  X51007339642.txt
# 1    UNIHAKKA INTERNATIONAL SDN BHD 10 MAR 2018 18:...  X51005433522.txt
# 2    DIGI TELECOMMUNICATIONS SDN BHD (201283 - M) L...  X51006555072.txt
# 3    MR. D. I. Y. (Metre) SDN BHD (CO. REG: 860671 ...  X51007103675.txt
# 4    HOME MASTER HARDWARE & ELECTRICAL NO. 113G & 1...  X51005301659.txt
# ..                                                 ...               ...
# 621  99 SPEED MART Sec / B (519537 - X) LOT P. T. 2...  X51005719883.txt
# 622  ZEN AND COFFEE 28 Entropy / B NO 53, JALAN 3 /...  X51005719906.txt
# 623  UNIHAKKA INTERNATIONAL SDN BHD 10 MAY 2018 12:...  X51006913030.txt
# 624  FARMASI MALURI S / B (587969 - U) GST NO: 0003...  X51005685357.txt
# 625  UNIHAKKA INTERNATIONAL SDN BHD 12 JUN 2018 18:...  X51007846307.txt
#
# [626 rows x 2 columns]

# %%
DataFrame_synonym.describe()
# Out:
#                                                      text           archivo
# count                                                 626               626
# unique                                                626               626
# top     AIK HUAT HARDWARE ENTERPRISE (SETIA ALAM) SDN ...  X51007339642.txt
# freq                                                    1                 1

# %%
# Evaluate the embedding text augmentation
# Evaluar el aumento de texto incrustado
DataFrame_embedding = evaluate_aug(
  aug_strategy = 'embedding',
  n = 1,
  train_df = DataFrame_synonym,
  dset_test = dset_test)
print(DataFrame_embedding)
# Out:
#                                                   text           archivo
# 0    aik huat hardware enterprise ( setia alam ) sd...  X51007339642.txt
# 1    unihakka international selangor bhd 10 mar 201...  X51005433522.txt
# 2    digi telecommunications ltd bhd ( 201283 - m )...  X51006555072.txt
# 3    mr. v. i. y. ( metre ) sdn bhd ( co. letters :...  X51007103675.txt
# 4    home master hardware & electrical corp. 113g &...  X51005301659.txt
# ..                                                 ...               ...
# 621  99 speed mart sec / b ( 519537 - x ) lot p. t....  X51005719883.txt
# 622  ham and coffee 28 entropy / b no 53, jalan 3 /...  X51005719906.txt
# 623  unihakka foundation sdn bhd 10 may 2018 member...  X51006913030.txt
# 624  farmasi maluri s / b ( 587969 - u ) gst no : 6...  X51005685357.txt
# 625  unihakka international sdn bhd 12 jun 2018 18 ...  X51007846307.txt
#
# [626 rows x 2 columns]

# %%
DataFrame_embedding.describe()
# Out:
#                                                      text           archivo
# count                                                 626               626
# unique                                                626               626
# top     aik huat hardware enterprise ( setia alam ) sd...  X51007339642.txt
# freq                                                    1                 1

# %%
train_df_augmented = pd.concat([train_df, DataFrame_embedding], axis = 0)

# %%
train_df_augmented.describe()
# Out:
#                                                      text           archivo
# count                                                1252              1252
# unique                                               1250               626
# top     B & BEST RESTAURANT (001610235-P) GST NO. : 00...  X51007339642.txt
# freq                                                    2                 2

# %%
# Evaluate the back translation text augmentation
# Evaluar el aumento de texto de traducción inversa
DataFrame_backtranslation = evaluate_aug(
  aug_strategy = 'backtranslation',
  n = 1,
  train_df = DataFrame_embedding,
  dset_test = dset_test)
print(DataFrame_backtranslation)
# Out:
#                                                   text           archivo
# 0    aik huat hardware enterprise (setia alam) sdn ...  X51007339642.txt
# 1    unihakka international selangor bhd March 10, ...  X51005433522.txt
# 2    digi telecommunications ltd bhd (201283 - m) l...  X51006555072.txt
# 3    mr. v. i. J. (Meter) sdn bhd (Co.-Letters: 860...  X51007103675.txt
# 4    home master hardware & electric corp. 113g & 1...  X51005301659.txt
# ..                                                 ...               ...
# 621  99 speed mart sec / b (519537 - x) lot p. t. 5...  X51005719883.txt
# 622  Ham and Coffee 28 entropy / b no 53, jalan 3 /...  X51005719906.txt
# 623  unihakka foundation sdn bhd 10 may 2018 member...  X51006913030.txt
# 624  farmasi maluri s / b (587969 - u) gst no: 66 (...  X51005685357.txt
# 625  unihakka international sdn bhd 12. June 2018 1...  X51007846307.txt
#
# [626 rows x 2 columns]

# %%
DataFrame_backtranslation.describe()
# Out:
#                                                      text           archivo
# count                                                 626               626
# unique                                                626               626
# top     aik huat hardware enterprise (setia alam) sdn ...  X51007339642.txt
# freq                                                    1                 1

# %%
train_df_augmented = pd.concat([train_df, DataFrame_backtranslation], axis = 0)
train_df_augmented.describe()
# Out:
#                                                      text           archivo
# count                                                1252              1252
# unique                                               1250               626
# top     B & BEST RESTAURANT (001610235-P) GST NO. : 00...  X51007339642.txt
# freq                                                    2                 2

# %%
train_df_augmented.to_parquet(path='/content/drive/MyDrive/Colab Notebooks/Datos/Sorieaumentation.parquet', index=False)
