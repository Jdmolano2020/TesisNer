# %% [markdown]
# <a href="https://colab.research.google.com/github/Jdmolano2020/TesisNer/blob/main/SroieTextAugmentationRead.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
# Mount Google drive to colab
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
train_df_augmented=pd.read_parquet(path='/content/drive/MyDrive/Colab Notebooks/Datos/Sorieaumentation.parquet', engine='pyarrow')

# %%
train_df_augmented.describe()
# Out:
#                                                      text           archivo
# count                                                1252              1252
# unique                                               1250               626
# top     B & BEST RESTAURANT (001610235-P) GST NO. : 00...  X51007339642.txt
# freq                                                    2                 2

# %%
train_df_augmented.head()
# Out:
#                                                 text           archivo
# 0  AIK HUAT HARDWARE ENTERPRISE (SETIA ALAM) SDN ...  X51007339642.txt
# 1  UNIHAKKA INTERNATIONAL SDN BHD 10 MAR 2018 18:...  X51005433522.txt
# 2  DIGI TELECOMMUNICATIONS SDN BHD (201283-M) LOT...  X51006555072.txt
# 3  MR. D.I.Y. (M) SDN BHD (CO.REG :860671-D) LOT ...  X51007103675.txt
# 4  HOME MASTER HARDWARE & ELECTRICAL NO.113G & 11...  X51005301659.txt

# %%
train_df_augmented.loc[1]
# Out:
# text       UNIHAKKA INTERNATIONAL SDN BHD 10 MAR 2018 18:...
# archivo                                     X51005433522.txt
# Name: 1, dtype: object
